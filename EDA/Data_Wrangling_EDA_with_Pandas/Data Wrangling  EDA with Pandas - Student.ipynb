# %% [markdown]
# In this project, we will analyze human resources data by performing data wrangling & EDA.
#
# We will learn how to:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # CODING TASK #1. IMPORT DATASET AND PERFORM BASIC STATISTICAL DATA ANALYSIS

# %% [markdown]
# - **Import Pandas Library**
#
# - **Force Pandas to display all rows and columns**
#
# - **Let's read a CSV file using Pandas as follows**
#
# - **Let's obtain the datatype**
#
# - **you can view the first couple of rows using .head()**
#
# - **you can view the last couple of rows using .tail()**
#
# - **Calculate the average values for employee_df dataframe**
#
# - **35 features in total**
#
# - **Obtain a Statistical Summary about the data**

# %%
#pd.set_option('display.max_columns', None)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Human_Resources.csv")
df.sample(3)
# Out:
#       Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 1243   45         9756.0        No  Travel_Rarely        176
# 471    38         9824.0        No  Travel_Rarely       1495
# 587    52         3149.0        No  Travel_Rarely       1325
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1243         Human Resources                 4          3  Life Sciences
# 471   Research & Development                10          3        Medical
# 587   Research & Development                11          4  Life Sciences
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 1243              1          1744.0                        3  Female
# 471               1           634.0                        3  Female
# 587               1           813.0                        4  Female
#
#       HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 1243          56               1         3            Human Resources
# ...

# %%
df.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1470.0     36.923810     9.135373    18.0    30.00
# MonthlyIncome             1467.0   6505.155419  4711.297846  1009.0  2911.00
# DailyRate                 1470.0    802.485714   403.509100   102.0   465.00
# DistanceFromHome          1470.0      9.192517     8.106864     1.0     2.00
# Education                 1470.0      2.912925     1.024165     1.0     2.00
# EmployeeCount             1470.0      1.000000     0.000000     1.0     1.00
# EmployeeNumber            1469.0   1025.556161   601.646166     1.0   492.00
# EnvironmentSatisfaction   1470.0      2.721769     1.093082     1.0     2.00
# HourlyRate                1470.0     65.891156    20.329428    30.0    48.00
# JobInvolvement            1470.0      2.729932     0.711561     1.0     2.00
# JobLevel                  1470.0      2.063946     1.106940     1.0     1.00
# ...

# %%
df.head(3)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
#
#    EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 0              1  ...                         1             80
# 1              1  ...                         4             80
# 2              1  ...                         2             80
#
#   StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  \
# 0                0                  8                      0                1
# ...

# %%
df.tail(3)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1467  Research & Development                 4          3  Life Sciences
# 1468                   Sales                 2          3        Medical
# 1469  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1467              1  ...                         2             80
# 1468              1  ...                         4             80
# 1469              1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1467                1                  6                      0
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #1:**
# - **Calculate the mean, maximum and minimum employee age considered in this study using a different strategy**

# %%
df["Age"].mean()
# Out:
# 36.923809523809524

# %%
df["Age"].max()
# Out:
# 60

# %%
df["Age"].min()
# Out:
# 18

# %%
df.sample(3)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 974    27         5071.0        No  Travel_Frequently        793
# 439    31         9824.0       Yes  Travel_Frequently        534
# 1275   51        13116.0        No      Travel_Rarely        942
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 974                    Sales                 2          1     Life Sciences
# 439   Research & Development                20          3     Life Sciences
# 1275  Research & Development                 3          3  Technical Degree
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 974               1  ...                         2             80
# 439               1  ...                         1             80
# 1275              1  ...                         4             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %% [markdown]
# # CODING TASK #2. DEALING WITH MISSING DATA

# %% [markdown]
# - **Let's locate rows that have Null values**
#
# - **Notice Row index 6 has many missing values**
#
# - **Let's see the total number of missing elements per column**
#
# - **Drop any row that contains a Null value**
#
# - **Note that the size of the dataframe has been reduced by 7 elements from 1470 to 1463**
#
# - **Notice that row 1 for example is no longer existing!**
#
# - **Let's check if we still have any missing values**
#
# - **Let's explore an alternative (smarter) method to deal with missing values**
#
# - **Let's read the raw data again using Pandas as follows**
#
# - **Calculate the average monthly income**
#
# - **You can use Fillna to fill a given column with a certain value**

# %%
df.sample(3)
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 982   38         2610.0        No  Travel_Frequently        693
# 875   44         4541.0        No      Travel_Rarely        200
# 735   48         4240.0        No      Travel_Rarely        277
#
#                  Department  DistanceFromHome  Education EducationField  \
# 982  Research & Development                 7          3  Life Sciences
# 875  Research & Development                29          4          Other
# 735  Research & Development                 6          3  Life Sciences
#
#      EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 982              1  ...                         4             80
# 875              1  ...                         2             80
# 735              1  ...                         4             80
#
#     StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 982                3                  4                      2
# ...

# %%
df.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df.shape
# Out:
# (1470, 35)

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
df.isnull().sum()[df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df.shape
# Out:
# (1463, 35)

# %%
df_1 = pd.read_csv("Human_Resources.csv")
df_1.sample(3)
# Out:
#       Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 1326   32         9907.0       Yes  Travel_Rarely        414
# 1071   49         4789.0        No  Travel_Rarely        271
# 712    33         3452.0        No  Travel_Rarely        461
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1326                   Sales                 2          4      Marketing
# 1071  Research & Development                 3          2        Medical
# 712   Research & Development                13          1  Life Sciences
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1326              1  ...                         3             80
# 1071              1  ...                         1             80
# 712               1  ...                         1             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1326                0                  7                      3
# ...

# %%
df_1.shape
# Out:
# (1470, 35)

# %%
df_1.isnull().sum()[df_1.isnull().sum()>0]
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
df_1.sample(3)
# Out:
#       Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 1046   44         3420.0        No  Travel_Rarely       1467
# 303    31         6929.0        No  Travel_Rarely        218
# 143    30         2632.0        No  Travel_Rarely        438
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1046  Research & Development                20          3     Life Sciences
# 303                    Sales                 7          3  Technical Degree
# 143   Research & Development                18          3     Life Sciences
#
#       EmployeeCount  ...  RelationshipSatisfaction  StandardHours  \
# 1046              1  ...                         3             80
# 303               1  ...                         2             80
# 143               1  ...                         3             80
#
#      StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 1046                0                  6                      3
# ...

# %%
df["Department"].value_counts().reset_index()
# Out:
#                Department  count
# 0  Research & Development    955
# 1                   Sales    445
# 2         Human Resources     63

# %%
df_1["Department"] = df_1["Department"].fillna("Research & Development")
df_1["Department"].isnull().sum()
# Out:
# 0

# %%
df_1["Department"].value_counts()
# Out:
# Department
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: count, dtype: int64

# %%
df_1["MonthlyIncome"].value_counts().reset_index()
# Out:
#       MonthlyIncome  count
# 0            2342.0      4
# 1            2451.0      3
# 2            2610.0      3
# 3            6142.0      3
# 4            6347.0      3
# ...             ...    ...
# 1341         6322.0      1
# 1342         7104.0      1
# 1343         2773.0      1
# 1344        19513.0      1
# 1345         4404.0      1
#
# [1346 rows x 2 columns]

# %%
df_1["MonthlyIncome"].mean()
# Out:
# 6505.155419222904

# %%
null_df_1 = df_1[df_1.isnull().any(axis=1)]
null_df_1
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 6     59            NaN        No      Travel_Rarely       1324
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 6    Research & Development                 3          3            NaN
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# 103  Research & Development                 6          4          Other
# 947                   Sales                 5          3  Life Sciences
#
# ...

# %%
df_1.isnull().sum()[df_1.isnull().sum()>0]
# Out:
# MonthlyIncome        3
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
df_1["PercentSalaryHike"]=df_1["PercentSalaryHike"].fillna(df_1["PercentSalaryHike"].mean())

# %%
df_1["PerformanceRating"]=df_1["PerformanceRating"].fillna(df_1["PerformanceRating"].mean())

# %%
df_1["MonthlyRate"]=df_1["MonthlyRate"].fillna(df_1["MonthlyRate"].mean())

# %%
#df_1["EmployeeNumber"]=df_1["EmployeeNumber"].fillna(df_1["EmployeeNumber"].mean())
#unique oldugundan dolduramayız...

# %%
df_1["EmployeeNumber"].value_counts()
# Out:
# EmployeeNumber
# 1.0       1
# 1392.0    1
# 1390.0    1
# 1389.0    1
# 1387.0    1
#          ..
# 661.0     1
# 659.0     1
# 657.0     1
# 656.0     1
# 2068.0    1
# Name: count, Length: 1469, dtype: int64

# %%
#df_1["MonthlyIncome"]=df_1["MonthlyIncome"].fillna(df_1["MonthlyIncome"].mean())
df_1["MonthlyIncome"]=df_1["MonthlyIncome"].fillna(df_1["MonthlyIncome"].median())

# %%
df_1["EducationField"]=df_1["EducationField"].fillna("Other")

# %%
df_1.isnull().sum()[df_1.isnull().sum()>0]
# Out:
# EmployeeNumber    1
# Gender            1
# JobRole           1
# MaritalStatus     1
# dtype: int64

# %%
df_1["Gender"].value_counts()
# Out:
# Gender
# Male      882
# Female    587
# Name: count, dtype: int64

# %%
df_1[df_1.isnull().any(axis=1)]
#null değeri getirecek
# Out:
#     Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 6    59         4908.0        No  Travel_Rarely       1324
# 17   22         2935.0        No     Non-Travel       1123
#
#                 Department  DistanceFromHome  Education EducationField  \
# 6   Research & Development                 3          3          Other
# 17  Research & Development                16          2        Medical
#
#     EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 6               1             NaN                        3    NaN          81
# 17              1            22.0                        4   Male          96
#
#     JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 6                4         1                    NaN                1
# 17               4         1  Laboratory Technician                4
#
#    MaritalStatus  MonthlyRate  NumCompaniesWorked Over18 OverTime  \
# ...

# %%
df_1.dropna(subset=["Gender"], inplace=True)

# %%
df_1.isnull().sum()[df_1.isnull().sum()>0]
# Out:
# MaritalStatus    1
# dtype: int64

# %%
df_1["EducationField"].value_counts()
# Out:
# EducationField
# Life Sciences       606
# Medical             463
# Marketing           159
# Technical Degree    132
# Other                82
# Human Resources      27
# Name: count, dtype: int64

# %%
df_1["MaritalStatus"].value_counts()
# Out:
# MaritalStatus
# Married     672
# Single      470
# Divorced    326
# Name: count, dtype: int64

# %%
df_1.dropna(subset=["MaritalStatus"], inplace=True)

# %%
df_1.isnull().sum()[df_1.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df_1.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
df_1.sample(1)
# Out:
#      Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 743   59        13726.0        No  Travel_Rarely        715
#
#                  Department  DistanceFromHome  Education EducationField  \
# 743  Research & Development                 2          3  Life Sciences
#
#      EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 743              1          1032.0                        3  Female
#
#      HourlyRate  JobInvolvement  JobLevel                 JobRole  \
# 743          69               2         4  Manufacturing Director
#
#      JobSatisfaction MaritalStatus  MonthlyRate  NumCompaniesWorked Over18  \
# 743                4        Single      21829.0                   3      Y
#
#     OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 743      Yes               13.0                3.0                         1
#
#      StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #2:**
# - **Calculate the median monthly rate. Use the calculated median values to fill out missing data. Confirm that the process is successful**

# %%
df_1["MonthlyRate"].median()
# Out:
# 4908.0

# %%
df_1["MonthlyRate"]=df_1["MonthlyRate"].fillna(df_1["MonthlyRate"].median())

# %%
df_1.sample(3)
# Out:
#       Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 1291   37         4213.0       Yes  Travel_Rarely        370
# 784    38         8823.0        No  Travel_Rarely        330
# 305    36         5674.0        No     Non-Travel       1105
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1291  Research & Development                10          4        Medical
# 784   Research & Development                17          1  Life Sciences
# 305   Research & Development                24          4  Life Sciences
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 1291              1          1809.0                        4    Male
# 784               1          1088.0                        3  Female
# 305               1           419.0                        2  Female
#
#       HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 1291          58               3         2     Manufacturing Director
# ...

# %% [markdown]
# # CODING TASK #3: PERFORM ONE-HOT ENCODING [OPTIONAL]

# %% [markdown]
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %% [markdown]
# ![2.png](data:image/png;base64,...)

# %% [markdown]
# ![1.png](data:image/png;base64,...)

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df.sample(1)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1239   31         5238.0        No  Travel_Frequently        163
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1239  Research & Development                24          1  Technical Degree
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 1239              1          1736.0                        4  Female
#
#       HourlyRate  JobInvolvement  JobLevel                 JobRole  \
# 1239          30               3         2  Manufacturing Director
#
#       JobSatisfaction MaritalStatus  MonthlyRate  NumCompaniesWorked Over18  \
# 1239                4        Single       6670.0                   2      Y
#
#      OverTime  PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 1239       No               20.0                4.0                         4
#
#       StandardHours  StockOptionLevel  TotalWorkingYears  \
# ...

# %%
hr_df.isnull().sum()[hr_df.isnull().sum()>0]
# Out:
# MonthlyIncome        3
# Department           1
# EducationField       1
# EmployeeNumber       1
# Gender               1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
hr_df.dropna(inplace=True)

# %%
hr_df.isnull().sum()[hr_df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
df['EducationField'].nunique()
# Out:
# 6

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['EducationField']
# Out:
# 0       Life Sciences
# 2               Other
# 3       Life Sciences
# 4             Medical
# 5       Life Sciences
#             ...
# 1465          Medical
# 1466          Medical
# 1467    Life Sciences
# 1468          Medical
# 1469          Medical
# Name: EducationField, Length: 1463, dtype: object

# %%
EducationField_Encoded = pd.get_dummies(hr_df['EducationField'])
EducationField_Encoded.head(15)
# Out:
#     Human Resources  Life Sciences  Marketing  Medical  Other  \
# 0             False           True      False    False  False
# 2             False          False      False    False   True
# 3             False           True      False    False  False
# 4             False          False      False     True  False
# 5             False           True      False    False  False
# 8             False           True      False    False  False
# 9             False          False      False     True  False
# 10            False          False      False     True  False
# 11            False           True      False    False  False
# 12            False           True      False    False  False
# 13            False          False      False     True  False
# 14            False           True      False    False  False
# 15            False           True      False    False  False
# 16            False           True      False    False  False
# ...

# %% [markdown]
# One-hot encoding, kategorik verileri makine öğrenimi modellerine daha uygun hale getirmek için kullanılan bir yöntem

# %%
hr_df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
hr_df['BusinessTravel']
# Out:
# 0           Travel_Rarely
# 2           Travel_Rarely
# 3       Travel_Frequently
# 4           Travel_Rarely
# 5       Travel_Frequently
#               ...
# 1465    Travel_Frequently
# 1466        Travel_Rarely
# 1467        Travel_Rarely
# 1468    Travel_Frequently
# 1469        Travel_Rarely
# Name: BusinessTravel, Length: 1463, dtype: object

# %%
BusinessTravel_Encoded = pd.get_dummies(hr_df['BusinessTravel'])
print(BusinessTravel_Encoded)
# Out:
#       Non-Travel  Travel_Frequently  Travel_Rarely
# 0          False              False           True
# 2          False              False           True
# 3          False               True          False
# 4          False              False           True
# 5          False               True          False
# ...          ...                ...            ...
# 1465       False               True          False
# 1466       False              False           True
# 1467       False              False           True
# 1468       False               True          False
# 1469       False              False           True
#
# [1463 rows x 3 columns]

# %% [markdown]
# **PRACTICE OPPORTUNITY #3 [OPTIONAL]:**
# - **Import the Human Resources data and remove all missing values**
# - **How many unique categories exist in the Education Field column?**
# - **Perform one hot encoding to the Education Field column**

# %%
#Yukarıda Yapıldı

# %% [markdown]
# # CODING TASK #4: PERFORM SCALING (NORMALIZATION & STANDARDIZATION) [OPTIONAL]

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')
hr_df.head(4)
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0   41         5993.0       Yes      Travel_Rarely       1102
# 1   49            NaN        No  Travel_Frequently        279
# 2   37         2090.0       Yes      Travel_Rarely       1373
# 3   33         2909.0        No  Travel_Frequently       1392
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
#
#    EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  HourlyRate  \
# 0              1             1.0                        2  Female          94
# 1              1             2.0                        3    Male          61
# ...

# %%
hr_df['Age'].values
# Out:
# array([41, 49, 37, ..., 27, 49, 34], dtype=int64)

# %%
# Normalization is conducted to make feature values range from 0 to 1
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['Age'] = scaler.fit_transform(hr_df['Age'].values.reshape(-1,1))

# %%
hr_df['Age']
# Out:
# 0       0.547619
# 1       0.738095
# 2       0.452381
# 3       0.357143
# 4       0.214286
# 5       0.333333
# 6       0.976190
# 7       0.285714
# 8       0.476190
# 9       0.428571
# 10      0.404762
# 11      0.261905
# 12      0.309524
# 13      0.380952
# 14      0.238095
# 15      0.261905
# 16      0.333333
# 17      0.095238
# 18      0.833333
# 19      0.476190
# 20      0.142857
# 21      0.428571
# 22      0.380952
# 23      0.071429
# 24      0.380952
# 25      0.833333
# 26      0.333333
# 27      0.571429
# 28      0.619048
# 29      0.666667
# 30      0.357143
# 31      0.619048
# 32      0.285714
# 33      0.500000
# 34      0.142857
# 35      0.595238
# 36      0.761905
# 37      0.404762
# 38      0.428571
# 39      0.357143
# 40      0.404762
# 41      0.214286
# 42      0.190476
# 43      0.214286
# 44      0.285714
# 45      0.547619
# 46      0.380952
# 47      0.452381
# 48      0.666667
# 49      0.404762
# 50      0.714286
# 51      0.238095
# ...

# %%
MonthlyIncome_desribe = hr_df.describe()["MonthlyIncome"]

# %%
MonthlyIncome_desribe
# Out:
# count     1467.000000
# mean      6505.155419
# std       4711.297846
# min       1009.000000
# 25%       2911.000000
# 50%       4908.000000
# 75%       8378.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# **PRACTICE OPPORTUNITY #4 [OPTIONAL]:**
# - **Perform feature scaling by performing standardization (Recall that Standardization is conducted to transform the data to have a mean of zero and standard deviation of 1.**
# - **Perform a sanity check to ensure that the transformation was successful**

# %%
hr_df['MonthlyIncome'].values
# Out:
# array([5993.,   nan, 2090., ..., 6142., 5390., 4404.])

# %%
hr_df.dropna(inplace=True)

# %%
hr_df_once = hr_df

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
hr_df['MonthlyIncome'] = scaler.fit_transform(hr_df['MonthlyIncome'].values.reshape(-1,1))

# %%
hr_df["MonthlyIncome"]
# Out:
# 0       0.262454
# 2       0.056925
# 3       0.100053
# 4       0.129489
# 5       0.108425
# 8       0.448499
# 9       0.222643
# 10      0.074618
# 11      0.167667
# 12      0.100158
# 13      0.086993
# 14      0.053660
# 15      0.472407
# 16      0.120537
# 18      0.759242
# 19      0.154555
# 20      0.158083
# 21      0.126277
# 22      0.578462
# 24      0.102738
# 25      0.952343
# 26      0.153239
# 27      0.306266
# 28      0.486519
# 29      0.944602
# 30      0.078304
# 31      0.287309
# 32      0.063033
# 33      0.056714
# 34      0.067615
# 35      0.086151
# 36      0.088152
# 37      0.052923
# 38      0.126909
# 39      0.229963
# 40      0.049605
# 41      0.070142
# 42      0.067615
# 43      0.406372
# 44      0.158083
# 45      0.976093
# 46      0.187414
# 47      0.106003
# 48      0.250816
# 49      0.066351
# 50      0.230226
# 51      0.128067
# 52      0.234071
# 53      0.467351
# 54      0.165771
# 55      0.655556
# 56      0.424434
# ...

# %% [markdown]
# # CODING TASK #5. PANDAS OPERATIONS/FILTERING

# %%
# Let's read a CSV file using Pandas as follows
hr_df = pd.read_csv('Human_Resources.csv')

# %% [markdown]
# - **Pick certain rows that satisfy a certain criteria**
#
# - **Pick certain rows that satisfy 2 or more critirea**
#
# - **values that fall between a given range**

# %%
hr_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
hr_df.sample(5)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1397   54         2897.0        No      Travel_Rarely        155
# 206    22         2328.0        No      Travel_Rarely       1136
# 728    54        10739.0        No      Travel_Rarely       1441
# 623    30         3761.0        No  Travel_Frequently       1012
# 949    39         4534.0        No      Travel_Rarely        524
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 1397  Research & Development                 9          2     Life Sciences
# 206   Research & Development                 5          3     Life Sciences
# 728   Research & Development                17          3  Technical Degree
# 623   Research & Development                 5          4     Life Sciences
# 949   Research & Development                18          2     Life Sciences
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
hr_df.groupby("Education")["EducationField"].value_counts(ascending=True)
# Out:
# Education  EducationField
# 1          Human Resources       2
#            Other                 5
#            Marketing            14
#            Technical Degree     19
#            Medical              63
#            Life Sciences        67
# 2          Human Resources       2
#            Other                19
#            Technical Degree     22
#            Marketing            24
#            Medical              99
#            Life Sciences       116
# 3          Human Resources      16
#            Other                24
#            Technical Degree     57
#            Marketing            59
#            Medical             182
#            Life Sciences       233
# 4          Human Resources       5
#            Technical Degree     31
#            Other                33
#            Marketing            52
#            Medical             104
#            Life Sciences       173
# 5          Other                 1
#            Human Resources       2
# ...

# %%
hr_df.groupby("Department")["MonthlyRate"].value_counts().reset_index().head(10)
# Out:
#         Department  MonthlyRate  count
# 0  Human Resources       2097.0      1
# 1  Human Resources      19555.0      1
# 2  Human Resources      26894.0      1
# 3  Human Resources      25811.0      1
# 4  Human Resources      25657.0      1
# 5  Human Resources      25527.0      1
# 6  Human Resources      24609.0      1
# 7  Human Resources      24017.0      1
# 8  Human Resources      23965.0      1
# 9  Human Resources      23648.0      1

# %%
hr_df.groupby("Department")["MonthlyRate"].mean()
# Out:
# Department
# Human Resources           13492.984127
# Research & Development    14282.524008
# Sales                     14489.793722
# Name: MonthlyRate, dtype: float64

# %%
hr_df.groupby("Department")["EducationField"].value_counts()
# Out:
# Department              EducationField
# Human Resources         Human Resources      27
#                         Life Sciences        16
#                         Medical              13
#                         Technical Degree      4
#                         Other                 3
# Research & Development  Life Sciences       439
#                         Medical             362
#                         Technical Degree     94
#                         Other                64
# Sales                   Marketing           159
#                         Life Sciences       150
#                         Medical              88
#                         Technical Degree     34
#                         Other                15
# Name: count, dtype: int64

# %%
hr_df.isnull().sum()
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
hr_df["Department"].fillna("Research & Development",inplace=True)

# %%
hr_df[hr_df.isnull().any(axis=1)]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 6     59            NaN        No      Travel_Rarely       1324
# 17    22         2935.0        No         Non-Travel       1123
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 6    Research & Development                 3          3            NaN
# 17   Research & Development                16          2        Medical
# 23   Research & Development                15          2  Life Sciences
# 103  Research & Development                 6          4          Other
# 947                   Sales                 5          3  Life Sciences
#
# ...

# %%
hr_df.groupby('Department')['MonthlyIncome'].mean()
# Out:
# Department
# Human Resources           6654.507937
# Research & Development    6286.218978
# Sales                     6955.831461
# Name: MonthlyIncome, dtype: float64

# %%
hr_df["EducationField"].fillna("Life Sciences",inplace=True)

# %%
hr_df.groupby("EducationField")["Department"].value_counts()
# Out:
# EducationField    Department
# Human Resources   Human Resources            27
# Life Sciences     Research & Development    441
#                   Sales                     150
#                   Human Resources            16
# Marketing         Sales                     159
# Medical           Research & Development    362
#                   Sales                      88
#                   Human Resources            13
# Other             Research & Development     64
#                   Sales                      15
#                   Human Resources             3
# Technical Degree  Research & Development     94
#                   Sales                      34
#                   Human Resources             4
# Name: count, dtype: int64

# %%
hr_df.groupby("EducationField")["BusinessTravel"].value_counts()
# Out:
# EducationField    BusinessTravel
# Human Resources   Travel_Rarely         17
#                   Travel_Frequently      6
#                   Non-Travel             4
# Life Sciences     Travel_Rarely        421
#                   Travel_Frequently    123
#                   Non-Travel            63
# Marketing         Travel_Rarely        120
#                   Travel_Frequently     27
#                   Non-Travel            12
# Medical           Travel_Rarely        327
#                   Travel_Frequently     86
#                   Non-Travel            50
# Other             Travel_Rarely         61
#                   Travel_Frequently     14
#                   Non-Travel             7
# Technical Degree  Travel_Rarely         97
#                   Travel_Frequently     21
#                   Non-Travel            14
# Name: count, dtype: int64

# %%
hr_df.groupby('Department')['Gender'].value_counts()
# Out:
# Department              Gender
# Human Resources         Male       43
#                         Female     20
# Research & Development  Male      582
#                         Female    378
# Sales                   Male      257
#                         Female    189
# Name: count, dtype: int64

# %%
hr_df['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
hr_df["Gender"].fillna("Male",inplace=True)

# %%
hr_df.isnull().sum()[hr_df.isnull().sum()>0]
# Out:
# MonthlyIncome        3
# EmployeeNumber       1
# JobRole              1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
hr_df.groupby("JobRole")["Department"].value_counts()
# Out:
# JobRole                    Department
# Healthcare Representative  Research & Development    131
# Human Resources            Human Resources            52
# Laboratory Technician      Research & Development    258
# Manager                    Research & Development     54
#                            Sales                      37
#                            Human Resources            11
# Manufacturing Director     Research & Development    145
# Research Director          Research & Development     80
# Research Scientist         Research & Development    292
# Sales Executive            Sales                     326
# Sales Representative       Sales                      83
# Name: count, dtype: int64

# %%
hr_df.groupby("JobRole")["EducationField"].value_counts()
# Out:
# JobRole                    EducationField
# Healthcare Representative  Life Sciences        60
#                            Medical              48
#                            Technical Degree     14
#                            Other                 9
# Human Resources            Human Resources      21
#                            Life Sciences        13
#                            Medical              11
#                            Technical Degree      4
#                            Other                 3
# Laboratory Technician      Life Sciences       119
#                            Medical              98
#                            Other                22
#                            Technical Degree     19
# Manager                    Life Sciences        40
#                            Medical              32
#                            Marketing            14
#                            Human Resources       6
#                            Technical Degree      5
# ...

# %%
hr_df["JobRole"].mode()
# Out:
# 0    Sales Executive
# Name: JobRole, dtype: object

# %%
hr_df["JobRole"].fillna("Sales Executive",inplace=True)

# %%
hr_df.groupby("JobLevel")["JobRole"].value_counts()
# Out:
# JobLevel  JobRole
# 1         Research Scientist           234
#           Laboratory Technician        199
#           Sales Representative          76
#           Human Resources               33
#           Sales Executive                1
# 2         Sales Executive              233
#           Manufacturing Director        90
#           Healthcare Representative     78
#           Research Scientist            57
#           Laboratory Technician         56
#           Human Resources               13
#           Sales Representative           7
# 3         Sales Executive               79
#           Manufacturing Director        45
#           Healthcare Representative     44
#           Research Director             28
#           Manager                       12
#           Human Resources                6
#           Laboratory Technician          3
#           Research Scientist             1
# 4         Manager                       47
# ...

# %%
hr_df.isnull().sum()[hr_df.isnull().sum()>0]
# Out:
# MonthlyIncome        3
# EmployeeNumber       1
# MaritalStatus        1
# MonthlyRate          2
# PercentSalaryHike    1
# PerformanceRating    1
# dtype: int64

# %%
hr_df.groupby("MaritalStatus")["Age"].mean()
# Out:
# MaritalStatus
# Divorced    37.536810
# Married     37.757801
# Single      35.336170
# Name: Age, dtype: float64

# %%
hr_df["MaritalStatus"][2]
# Out:
# 'Single'

# %%
hr_df["MaritalStatus"].fillna(hr_df["MaritalStatus"][2],inplace=True)

# %%
#pd.set_option('display.max_rows', None) #tüm satırları gösterme kodu Boolen 
#pd.reset_set_option('display.max_rows', None)

# %%
hr_df[hr_df.isnull().any(axis=1)]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 23   Research & Development                15          2  Life Sciences
# 103  Research & Development                 6          4          Other
# 947                   Sales                 5          3  Life Sciences
#
#      EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 1                1             2.0                        3    Male
# 23               1            30.0                        3    Male
# 103              1           138.0                        1  Female
# ...

# %%
hr_df[hr_df.isnull().any(axis=1)][1:2]
# Out:
#     Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 23   21         1232.0        No  Travel_Rarely        391
#
#                 Department  DistanceFromHome  Education EducationField  \
# 23  Research & Development                15          2  Life Sciences
#
#     EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  HourlyRate  \
# 23              1            30.0                        3   Male          96
#
#     JobInvolvement  JobLevel             JobRole  JobSatisfaction  \
# 23               3         1  Research Scientist                4
#
#    MaritalStatus  MonthlyRate  NumCompaniesWorked Over18 OverTime  \
# 23        Single          NaN                   1      Y       No
#
#     PercentSalaryHike  PerformanceRating  RelationshipSatisfaction  \
# 23               14.0                3.0                         4
#
#     StandardHours  StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# ...

# %%
hr_df.drop(6,inplace=True)
hr_df[hr_df.isnull().any(axis=1)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 hr_df.drop(6,inplace=True)
#       2 hr_df[hr_df.isnull().any(axis=1)]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:5347, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5199 def drop(
#    5200     self,
#    5201     labels: IndexLabel | None = None,
#    (...)
#    5208     errors: IgnoreRaise = "raise",
#    5209 ) -> DataFrame | None:
#    5210     """
#    5211     Drop specified labels from rows or columns.
#    5212
#    (...)
#    5345             weight  1.0     0.8
#    5346     """
# -> 5347     return super().drop(
#    5348         labels=labels,
#    5349         axis=axis,
#    5350         index=index,
#    5351         columns=columns,
# ...

# %%
hr_df[hr_df.isnull().any(axis=1)]
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1     49            NaN        No  Travel_Frequently        279
# 23    21         1232.0        No      Travel_Rarely        391
# 103   34         4809.0        No      Travel_Rarely        665
# 947   52            NaN       Yes      Travel_Rarely       1030
#
#                  Department  DistanceFromHome  Education EducationField  \
# 1    Research & Development                 8          1  Life Sciences
# 23   Research & Development                15          2  Life Sciences
# 103  Research & Development                 6          4          Other
# 947                   Sales                 5          3  Life Sciences
#
#      EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# 1                1             2.0                        3    Male
# 23               1            30.0                        3    Male
# 103              1           138.0                        1  Female
# ...

# %%
hr_df.isnull().sum()[hr_df.isnull().sum()>0]
# Out:
# MonthlyIncome    2
# MonthlyRate      2
# dtype: int64

# %%
hr_df["MonthlyIncome"].unique()
# Out:
# array([5993.,   nan, 2090., ..., 9991., 5390., 4404.])

# %%
hr_df["MonthlyIncome"].mode()
# Out:
# 0    2342.0
# Name: MonthlyIncome, dtype: float64

# %%
hr_df["MonthlyIncome"].value_counts()
# Out:
# MonthlyIncome
# 2342.0     4
# 2451.0     3
# 2610.0     3
# 6142.0     3
# 6347.0     3
#           ..
# 6322.0     1
# 7104.0     1
# 2773.0     1
# 19513.0    1
# 4404.0     1
# Name: count, Length: 1346, dtype: int64

# %%
hr_df["MonthlyIncome"].fillna(hr_df["MonthlyIncome"].mode()[0],inplace=True)

# %%
hr_df.groupby("Department")["MonthlyIncome"].value_counts()
# Out:
# Department       MonthlyIncome
# Human Resources  1555.0           1
#                  19658.0          1
#                  19189.0          1
#                  19141.0          1
#                  18844.0          1
#                                  ..
# Sales            5666.0           1
#                  5647.0           1
#                  5617.0           1
#                  5605.0           1
#                  19847.0          1
# Name: count, Length: 1390, dtype: int64

# %%
hr_df.groupby("Department")["MonthlyIncome"].mean()
# Out:
# Department
# Human Resources           6654.507937
# Research & Development    6282.110417
# Sales                     6945.486547
# Name: MonthlyIncome, dtype: float64

# %%
hr_df["MonthlyRate"].value_counts()
# Out:
# MonthlyRate
# 4223.0     3
# 9150.0     3
# 6670.0     2
# 21534.0    2
# 12858.0    2
#           ..
# 19627.0    1
# 14561.0    1
# 2671.0     1
# 5718.0     1
# 10228.0    1
# Name: count, Length: 1424, dtype: int64

# %%
hr_df["MonthlyRate"].mode()
# Out:
# 0    4223.0
# 1    9150.0
# Name: MonthlyRate, dtype: float64

# %%
hr_df["MonthlyRate"].mode()[0]
# Out:
# 4223.0

# %%
hr_df["MonthlyRate"].fillna(hr_df["MonthlyRate"].mode()[0],inplace=True)

# %%
hr_df.isnull().sum()[hr_df.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
hr_df.sample(10)
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 432    34         2768.0        No      Travel_Rarely       1303
# 401    56        13212.0        No  Travel_Frequently        906
# 1009   58        19701.0        No      Travel_Rarely       1055
# 785    40        10322.0        No      Travel_Rarely       1492
# 50     48         5381.0       Yes      Travel_Rarely        626
# 246    33         2911.0        No      Travel_Rarely        832
# 83     38         5329.0        No         Non-Travel        573
# 532    47         4960.0        No      Travel_Rarely        703
# 383    22         2244.0        No      Travel_Rarely        253
# 1136   28         2408.0       Yes      Travel_Rarely        329
#
#                   Department  DistanceFromHome  Education    EducationField  \
# 432   Research & Development                 2          4     Life Sciences
# 401                    Sales                 6          3     Life Sciences
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #5:**
# - **Using "hr_df" DataFrame, leverage pandas operations to only select high DailyRate individuals (1450+)**
# - **What is the combined Daily Rate for all employees with 1450+?**

# %%
hr_df[hr_df["DailyRate"] >= 1450].head(5)
# Out:
#      Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 31    44         6465.0        No      Travel_Rarely       1459
# 52    44         5454.0        No      Travel_Rarely       1488
# 110   51         7484.0        No  Travel_Frequently       1456
# 117   36         9738.0        No  Travel_Frequently       1467
# 155   29         4319.0        No         Non-Travel       1496
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 31   Research & Development                10          4             Other
# 52                    Sales                 1          5         Marketing
# 110  Research & Development                 1          4           Medical
# 117                   Sales                11          2  Technical Degree
# 155  Research & Development                 1          1  Technical Degree
#
#      EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  Gender  \
# ...

# %%
hr_df[hr_df["DailyRate"] >= 1450]["DailyRate"].sum()
# Out:
# 73749

# %% [markdown]
# # CODING TASK #6: PERFORM BASIC EDA ON BOTH CLASSES

# %% [markdown]
# - **It makes sense to drop 'EmployeeCount', 'Standardhours' and 'Over18' since they do not change from one employee to the other**
# - **Let's see how many employees left the company! Let's drop 'EmployeeNumber' as well**
# - **Let's see how many employees left the company!**
# - **View employees who left**

# %%
hr_df.drop(["EmployeeCount","StandardHours","Over18"],axis=1,inplace=True)

# %%
hr_df.drop(["EmployeeNumber"],axis=1,inplace=True)

# %%
hr_df["Attrition"].value_counts().get("Yes",0)
# Out:
# 237

# %%
hr_df["Attrition"]=="Yes"
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1465    False
# 1466    False
# 1467    False
# 1468    False
# 1469    False
# Name: Attrition, Length: 1469, dtype: bool

# %%
hr_df[hr_df["Attrition"]=="Yes"].head(3)
# Out:
#     Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 0    41         5993.0       Yes  Travel_Rarely       1102
# 2    37         2090.0       Yes  Travel_Rarely       1373
# 14   28         2028.0       Yes  Travel_Rarely        103
#
#                 Department  DistanceFromHome  Education EducationField  \
# 0                    Sales                 1          2  Life Sciences
# 2   Research & Development                 2          2          Other
# 14  Research & Development                24          3  Life Sciences
#
#     EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                         2  Female          94               3         2
# 2                         4    Male          92               2         1
# 14                        3    Male          50               2         1
#
#                   JobRole  JobSatisfaction MaritalStatus  MonthlyRate  \
# ...

# %% [markdown]
# **PRACTICE OPPORTUNITY #6:**
# - **Filter the hr_df to only include the employees who stayed in the company**
# - **Generate statistical summary for employees who stayed**
# - **Compare both statistical summaries. What do you infer from the data?**

# %%
hr_df[hr_df["Attrition"]=="No"].head()
# Out:
#    Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 1   49         2342.0        No  Travel_Frequently        279
# 3   33         2909.0        No  Travel_Frequently       1392
# 4   27         3468.0        No      Travel_Rarely        591
# 5   32         3068.0        No  Travel_Frequently       1005
# 7   30         2693.0        No      Travel_Rarely       1358
#
#                Department  DistanceFromHome  Education EducationField  \
# 1  Research & Development                 8          1  Life Sciences
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
# 5  Research & Development                 2          2  Life Sciences
# 7  Research & Development                24          1  Life Sciences
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 1                        3    Male          61               2         2
# ...

# %%
(hr_df[hr_df["Attrition"]=="No"]).describe().T
# Out:
#                            count          mean          std     min      25%  \
# Age                       1232.0     37.543831     8.870933    18.0    31.00
# MonthlyIncome             1232.0   6833.855519  4820.159366  1051.0  3210.75
# DailyRate                 1232.0    812.089286   403.108374   102.0   477.00
# DistanceFromHome          1232.0      8.920455     8.014112     1.0     2.00
# Education                 1232.0      2.926948     1.027417     1.0     2.00
# EnvironmentSatisfaction   1232.0      2.771104     1.071547     1.0     2.00
# HourlyRate                1232.0     65.939935    20.384516    30.0    48.00
# JobInvolvement            1232.0      2.769481     0.691443     1.0     2.00
# JobLevel                  1232.0      2.146916     1.117910     1.0     1.00
# JobSatisfaction           1232.0      2.780032     1.092545     1.0     2.00
# MonthlyRate               1232.0  14250.344968  7113.976272  2094.0  7912.75
# ...

# %%
avg_income_attrition_yes = hr_df[hr_df["Attrition"] == "Yes"]["Age"].mean()
avg_income_attrition_no = hr_df[hr_df["Attrition"] == "No"]["Age"].mean()

print(f"Ayrılanlar için aylık gelir ortalaması: {avg_income_attrition_yes:.1f}")
print(f"Ayrılmayanlar için aylık gelir ortalaması: {avg_income_attrition_no:.1f}")
# Out:
# Ayrılanlar için aylık gelir ortalaması: 33.6
# Ayrılmayanlar için aylık gelir ortalaması: 37.5

# %%
# Ayrılanlar ve ayrılmayanlar için aylık gelir ortalamalarını hesapla
avg_income_attrition_yes = hr_df[hr_df["Attrition"] == "Yes"]["MonthlyIncome"].mean()
avg_income_attrition_no = hr_df[hr_df["Attrition"] == "No"]["MonthlyIncome"].mean()

print(f"Ayrılanlar için aylık gelir ortalaması: {avg_income_attrition_yes:.0f}")
print(f"Ayrılmayanlar için aylık gelir ortalaması: {avg_income_attrition_no:.0f}")
# Out:
# Ayrılanlar için aylık gelir ortalaması: 4761
# Ayrılmayanlar için aylık gelir ortalaması: 6834

# %%
# Ayrılanlar ve ayrılmayanlar için iş memnuniyeti ortalamalarını hesapla
avg_satisfaction_attrition_yes = hr_df[hr_df["Attrition"] == "Yes"]["JobSatisfaction"].mean()
avg_satisfaction_attrition_no = hr_df[hr_df["Attrition"] == "No"]["JobSatisfaction"].mean()

print(f"Ayrılanlar için iş memnuniyeti ortalaması: {avg_satisfaction_attrition_yes:.1f}")
print(f"Ayrılmayanlar için iş memnuniyeti ortalaması: {avg_satisfaction_attrition_no:.1f}")
# Out:
# Ayrılanlar için iş memnuniyeti ortalaması: 2.5
# Ayrılmayanlar için iş memnuniyeti ortalaması: 2.8

# %% [markdown]
# # CODING TASK #7. PANDAS WITH FUNCTIONS

# %%
# Let's read a CSV file using Pandas as follows
hr_df_2 = pd.read_csv('Human_Resources.csv')
hr_df_2.sample(3)
# Out:
#       Age  MonthlyIncome Attrition BusinessTravel  DailyRate  \
# 1427   40         2406.0        No  Travel_Rarely        543
# 768    40         8396.0        No  Travel_Rarely        300
# 1098   40         4069.0        No     Non-Travel       1142
#
#                   Department  DistanceFromHome  Education EducationField  \
# 1427  Research & Development                 1          4  Life Sciences
# 768                    Sales                26          3      Marketing
# 1098  Research & Development                 8          2  Life Sciences
#
#       EmployeeCount  EmployeeNumber  EnvironmentSatisfaction Gender  \
# 1427              1          2012.0                        1   Male
# 768               1          1066.0                        3   Male
# 1098              1          1552.0                        4   Male
#
#       HourlyRate  JobInvolvement  JobLevel                    JobRole  \
# 1427          83               3         1      Laboratory Technician
# ...

# %%
hr_df_2[["MonthlyIncome","MonthlyRate"]].head(5)
# Out:
#    MonthlyIncome  MonthlyRate
# 0         5993.0      19479.0
# 1            NaN      24907.0
# 2         2090.0       2396.0
# 3         2909.0      23159.0
# 4         3468.0      16632.0

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %%
#hr_df_2["DailyRate"] = hr_df_2["DailyRate"].apply(lambda x : x * 1.10 )

# %% [markdown]
# - **Let's assume the daily rate has increased by 10%**
# - **Define a function that increases all clients networth by a fixed value of 10% (for simplicity sake)**
# - **assume that net worth increased by 10%**
# - **You can apply a function to the DataFrame**

# %% [markdown]
# burda ilk iki madde aynı şeyi ifade ediyor, iki kere yapmaya gerek yok. Bunu apply fonksiyonu ile yapın demek istedik aslında. Siz bunu bir fonksiyon oluşturup apply ile yapmışsınız. Sadece bunu kullansanız yeterli.

# %% [markdown]
# - **Günlük faizin %10 arttığını varsayalım**
# - **Tüm istemcilerin net değerini %10'luk sabit bir değerle artıran bir işlev tanımlayın (basitlik açısından)**
# - **net değerin %10 arttığını varsayalım**
# - **DataFrame'e bir işlev uygulayabilirsiniz**

# %%
#hr_df_2 = hr_df_2.apply(lambda x : x * 1.10 )

# %%
hr_df_2['NetWorth'] = hr_df_2['MonthlyIncome']
def increase_networth(row):
    return row['NetWorth'] * 1.1

hr_df_2['NetWorth'] = hr_df_2.apply(increase_networth, axis=1)

# %% [markdown]
# **PRACTICE OPPORTUNITY #7:**
# - **Define a function that doubles the DailyRate and adds $100**
# - **Apply the function to the DataFrame**
# - **Calculate the updated total Daily Rate of all employees combined**

# %% [markdown]
# **Günlük Oranı ikiye katlayan ve 100$ ekleyen bir işlev tanımlayın**
# - **İşlevi DataFrame'e uygulayın**
# - **Tüm çalışanların toplam güncellenmiş toplam Günlük Ücretini hesaplayın**

# %%
hr_df_2.columns
# Out:
# Index(['Age', 'MonthlyIncome', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeCount', 'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender',
#        'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager', 'NetWorth'],
#       dtype='object')

# %%
#Günlük Orani ikiye katlayan ve 100$ ekleyen bir işlev tanimlayin
def double_and_add_100(row):
    # "DailyRate" sütununu iki katına çıkar ve 100 ekler
    return row['DailyRate'] * 2 + 100

# %%
#İşlevi DataFrame'e uygulayın
hr_df['UpdatedDailyRate'] = hr_df.apply(double_and_add_100, axis=1)

# %%
#Tüm çalışanların toplam güncellenmiş toplam Günlük Ücretini hesaplayın
hr_df['UpdatedDailyRate'].sum()
# Out:
# 2503560

# %% [markdown]
# # CODING TASK #8: HISTOGRAM AND CORRELATION

# %% [markdown]
# - **Several features such as 'MonthlyIncome' and 'TotalWorkingYears' are tail heavy**
# - **Job level is strongly correlated with total working hours**
# - **Monthly income is strongly correlated with Job level**
# - **Monthly income is strongly correlated with total working hours**
# - **Age is strongly correlated with monthly income**

# %% [markdown]
# - **'AylıkGelir' ve 'ToplamÇalışmaYılları' gibi çeşitli özellikler çok önemlidir**
# - **İş düzeyi toplam çalışma saatleriyle güçlü bir şekilde ilişkilidir**
# - **Aylık gelir, İş seviyesiyle güçlü bir şekilde ilişkilidir**
# - **Aylık gelir toplam çalışma saatleriyle güçlü bir şekilde ilişkilidir**
# - **Yaş, aylık gelirle güçlü bir korelasyona sahiptir**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 1)
sns.histplot(data=hr_df_2, x='MonthlyIncome', bins=30, kde=True, color='blue')
plt.title('Monthly Income Distribution')
# Out:
# Text(0.5, 1.0, 'Monthly Income Distribution')

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 2)
sns.histplot(data=hr_df_2, x='TotalWorkingYears', bins=30, kde=True, color='blue')
plt.title('TotalWorkingYears Distribution')
# Out:
# Text(0.5, 1.0, 'TotalWorkingYears Distribution')

# %%
plt.subplot(1,2,1)
sns.histplot(hr_df_2["MonthlyIncome"], bins=20,kde=True,color="red")

plt.subplot(1,2,2)
sns.histplot(hr_df_2["TotalWorkingYears"], bins=20,kde=True,color="blue")
# Out:
# <Axes: xlabel='TotalWorkingYears', ylabel='Count'>

# %%
plt.figure(figsize=(12, 8))
plt.subplot(2, 2, 3)
sns.histplot(data=hr_df_2, x='TotalWorkingYears', bins=30, kde=True, color='green')
plt.title('Total Working Years Distribution')
# Out:
# Text(0.5, 1.0, 'Total Working Years Distribution')

# %%
correlation_matrix = df[['JobLevel', 'TotalWorkingYears', 'MonthlyIncome', 'Age']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# **PRACTICE OPPORTUNITY #8:**
# - **Change the color of the heatmap [External Research is Required]**

# %%
correlation_matrix = df[['JobLevel', 'TotalWorkingYears', 'MonthlyIncome', 'Age']].corr()
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# # EXCELLENT JOB!

# %% [markdown]
# # FINAL CAPSTONE PROJECT OVERVIEW

# %% [markdown]
# - In this project, we will perform basic Exploratory Data Analysis (EDA) on the Kyphosis disease Dataset.
# - Kyphosis is an abnormally excessive convex curvature of the spine.
# - Dataset contains 81 rows and 4 columns representing data on children who have had corrective spinal surgery.
#     - INPUTS: 1. Age: in months, 2. Number: the number of vertebrae involved, 3. Start: the number of the first (topmost) vertebra operated on.
#     - OUTPUTS: Kyphosis which represents a factor with levels absent present indicating if a kyphosis (a type of deformation) was present after the operation.
# - Using the “kyphosis.csv" included in the course package, write a python script to perform the following tasks:
#     1. Import the “kyphosis.csv" file using Pandas
#     2. Perform basic Exploratory Data Analysis (EDA) on the data
#     3. List the average, minimum and maximum age (in years) considered in this study using 2 methods
#     4. Plot the correlation matrix
#     5. Convert the age column datatype from int64 to float64
#     6. Define a function that converts age from months to years
#     7. Apply the function to the “Age” column and add the results into a new column entitled “Age in Years”
#     8. What are the features of the oldest and youngest child in this study?
#     9. Scale the raw Age column (in months) using both standardization and Normalization. Perform a sanity check.
#     10. Normalization is conducted on the 'Age' column to make feature values range from 0 to 1.

# %% [markdown]
#  Bu projede Kifoz Hastalığı Veri Kümesi üzerinde temel Keşifsel Veri Analizi (EDA) gerçekleştireceğiz.
# - Kifoz, omurganın anormal derecede aşırı dışbükey eğriliğidir.
# - Veri seti, düzeltici omurga ameliyatı geçiren çocuklara ilişkin verileri temsil eden 81 satır ve 4 sütun içermektedir.
#     - GİRİŞLER: 1. Yaş: ay cinsinden, 2. Sayı: ilgili omur sayısı, 3. Başlangıç: ameliyat edilen ilk (en üstteki) omur sayısı.
#     - ÇIKTILAR: Operasyondan sonra bir kifozun (bir tür deformasyon) mevcut olup olmadığını gösteren mevcut olmayan seviyelerin olduğu bir faktörü temsil eden kifoz.
# - Kurs paketindeki “kyphosis.csv”yi kullanarak aşağıdaki görevleri gerçekleştirmek için bir python betiği yazın:
#     1. Pandas'ı kullanarak “kyphosis.csv” dosyasını içe aktarın
#     2. Veriler üzerinde temel Keşif Veri Analizi (EDA) gerçekleştirin
#     3. Bu çalışmada dikkate alınan ortalama, minimum ve maksimum yaşı (yıl olarak) 2 yöntem kullanarak listeleyin
#     4. Korelasyon matrisini çizin
#     5. Yaş sütunu veri türünü int64'ten float64'e dönüştürün
#     6. Yaşı aylardan yıllara dönüştüren bir fonksiyon tanımlayın
#     7. Fonksiyonu "Yaş" sütununa uygulayın ve sonuçları "Yıllara Göre Yaş" başlıklı yeni bir sütuna ekleyin.
#     8. Bu çalışmadaki en büyük ve en küçük çocuğun özellikleri nelerdir?
#     9. Hem standardizasyonu hem de Normalleştirmeyi kullanarak ham Yaş sütununu (ay cinsinden) ölçeklendirin. Sağlamlık kontrolü yapın.
#     10. Özellik değerlerinin 0 ile 1 arasında değişmesi için 'Yaş' sütununda normalizasyon gerçekleştirilir.

# %%
#Pandas'ı kullanarak “kyphosis.csv” dosyasını içe aktarın

kyphosis=pd.read_csv("kyphosis.csv")
kyphosis
# Out:
#    Kyphosis  Age  Number  Start
# 0    absent   71       3      5
# 1    absent  158       3     14
# 2   present  128       4      5
# 3    absent    2       5      1
# 4    absent    1       4     15
# ..      ...  ...     ...    ...
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13
#
# [81 rows x 4 columns]

# %%
#2. Veriler üzerinde temel Keşif Veri Analizi (EDA) gerçekleştirin

kyphosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     int64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 2.7+ KB

# %%
kyphosis.head(3)
# Out:
#   Kyphosis  Age  Number  Start
# 0   absent   71       3      5
# 1   absent  158       3     14
# 2  present  128       4      5

# %%
kyphosis.tail(10)
# Out:
#    Kyphosis  Age  Number  Start
# 71   absent  127       4     12
# 72   absent   87       4     16
# 73   absent  206       4     10
# 74   absent   11       3     15
# 75   absent  178       4     15
# 76  present  157       3     13
# 77   absent   26       7     13
# 78   absent  120       2     13
# 79  present   42       7      6
# 80   absent   36       4     13

# %%
kyphosis.isnull().sum()[kyphosis.isnull().sum()>0]
# Out:
# Series([], dtype: int64)

# %%
kyphosis["Age"]=kyphosis["Age"].astype(float)

# %%
#6. Yaşı aylardan yıllara dönüştüren bir fonksiyon tanımlayın

def month_to_year(month):
    return month / 12.0

# %%
#7. Fonksiyonu "Yaş" sütununa uygulayın ve sonuçları "Yıllara Göre Yaş" başlıklı yeni bir sütuna ekleyin.

kyphosis["Age_Year"]=kyphosis["Age"].apply(month_to_year)

# %%
kyphosis["Age_Year"] = kyphosis["Age_Year"].round()

# %%
kyphosis.head(10)
# Out:
#   Kyphosis    Age  Number  Start  Age_Year
# 0   absent   71.0       3      5       6.0
# 1   absent  158.0       3     14      13.0
# 2  present  128.0       4      5      11.0
# 3   absent    2.0       5      1       0.0
# 4   absent    1.0       4     15       0.0
# 5   absent    1.0       2     16       0.0
# 6   absent   61.0       2     17       5.0
# 7   absent   37.0       3     16       3.0
# 8   absent  113.0       2     16       9.0
# 9  present   59.0       6     12       5.0

# %%
kyphosis.describe().T
# Out:
#           count       mean        std  min   25%   50%    75%    max
# Age        81.0  83.654321  58.104251  1.0  26.0  87.0  130.0  206.0
# Number     81.0   4.049383   1.619423  2.0   3.0   4.0    5.0   10.0
# Start      81.0  11.493827   4.883962  1.0   9.0  13.0   16.0   18.0
# Age_Year   81.0   7.000000   4.868265  0.0   2.0   7.0   11.0   17.0

# %%
#3. Bu çalışmada dikkate alınan ortalama, minimum ve maksimum yaşı (yıl olarak) 2 yöntem kullanarak listeleyin
mean_age = kyphosis['Age_Year'].mean()
min_age = kyphosis['Age_Year'].min()
max_age = kyphosis['Age_Year'].max()
print(mean_age)
print(min_age)
print(max_age)
# Out:
# 7.0
# 0.0
# 17.0

# %%
#3. Bu çalışmada dikkate alınan ortalama, minimum ve maksimum yaşı (yıl olarak) 2 yöntem kullanarak listeleyin

kyphosis['Age_Year'].describe()[['mean', 'min', 'max']]
# Out:
# mean     7.0
# min      0.0
# max     17.0
# Name: Age_Year, dtype: float64

# %%
kyphosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     float64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
#  4   Age_Year  81 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 3.3+ KB

# %%
#4. Korelasyon matrisini çizin

kyphosis[[ 'Number','Start','Age_Year']].corr()
# Out:
#             Number     Start  Age_Year
# Number    1.000000 -0.425099 -0.004757
# Start    -0.425099  1.000000  0.047316
# Age_Year -0.004757  0.047316  1.000000

# %%
#5. Yaş sütunu veri türünü int64'ten float64'e dönüştürün
#kyphosis["Age"]=kyphosis["Age"].astype(float)
kyphosis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kyphosis  81 non-null     object
#  1   Age       81 non-null     float64
#  2   Number    81 non-null     int64
#  3   Start     81 non-null     int64
#  4   Age_Year  81 non-null     float64
# dtypes: float64(2), int64(2), object(1)
# memory usage: 3.3+ KB

# %%
#8. Bu çalışmadaki en büyük ve en küçük çocuğun özellikleri nelerdir?
kyphosis[kyphosis['Age'] == kyphosis['Age'].min()]
# Out:
#    Kyphosis  Age  Number  Start  Age_Year
# 4    absent  1.0       4     15       0.0
# 5    absent  1.0       2     16       0.0
# 13   absent  1.0       4     12       0.0
# 15   absent  1.0       3     16       0.0
# 36   absent  1.0       3      9       0.0

# %%
kyphosis[kyphosis['Age'] == kyphosis['Age'].max()]
# Out:
#    Kyphosis    Age  Number  Start  Age_Year
# 73   absent  206.0       4     10      17.0

# %%
#pip install scikit-learn

# %%
#9. Hem standardizasyonu hem de Normalleştirmeyi kullanarak ham Yaş sütununu (ay cinsinden) ölçeklendirin. Sağlamlık kontrolü yapın.
from sklearn.preprocessing import StandardScaler, MinMaxScaler

scaler_standard = StandardScaler()
kyphosis['Age_Standardized'] = scaler_standard.fit_transform(kyphosis[['Age']])

scaler_minmax = MinMaxScaler()
kyphosis['Age_Normalized'] = scaler_minmax.fit_transform(kyphosis[['Age']])

# %%
kyphosis[['Age_Standardized',"Age","Age_Normalized"]].head(20)
# Out:
#     Age_Standardized    Age  Age_Normalized
# 0          -0.219143   71.0        0.341463
# 1           1.287494  158.0        0.765854
# 2           0.767964  128.0        0.619512
# 3          -1.414063    2.0        0.004878
# 4          -1.431381    1.0        0.000000
# 5          -1.431381    1.0        0.000000
# 6          -0.392320   61.0        0.292683
# 7          -0.807944   37.0        0.175610
# 8           0.508199  113.0        0.546341
# 9          -0.426956   59.0        0.282927
# 10         -0.028649   82.0        0.395122
# 11          1.114318  148.0        0.717073
# 12         -1.136980   18.0        0.082927
# 13         -1.431381    1.0        0.000000
# 14          1.460671  168.0        0.814634
# 15         -1.431381    1.0        0.000000
# 16         -0.097920   78.0        0.375610
# 17          1.581895  175.0        0.848780
# 18         -0.063284   80.0        0.385366
# 19         -0.981121   27.0        0.126829

# %%
kyphosis['Age_Standardized'].reset_index().head(20)
# Out:
#     index  Age_Standardized
# 0       0         -0.219143
# 1       1          1.287494
# 2       2          0.767964
# 3       3         -1.414063
# 4       4         -1.431381
# 5       5         -1.431381
# 6       6         -0.392320
# 7       7         -0.807944
# 8       8          0.508199
# 9       9         -0.426956
# 10     10         -0.028649
# 11     11          1.114318
# 12     12         -1.136980
# 13     13         -1.431381
# 14     14          1.460671
# 15     15         -1.431381
# 16     16         -0.097920
# 17     17          1.581895
# 18     18         -0.063284
# 19     19         -0.981121

# %%
kyphosis['Age_Normalized'].reset_index().head(20)
# Out:
#     index  Age_Normalized
# 0       0        0.341463
# 1       1        0.765854
# 2       2        0.619512
# 3       3        0.004878
# 4       4        0.000000
# 5       5        0.000000
# 6       6        0.292683
# 7       7        0.175610
# 8       8        0.546341
# 9       9        0.282927
# 10     10        0.395122
# 11     11        0.717073
# 12     12        0.082927
# 13     13        0.000000
# 14     14        0.814634
# 15     15        0.000000
# 16     16        0.375610
# 17     17        0.848780
# 18     18        0.385366
# 19     19        0.126829

# %%
scaler = MinMaxScaler()
kyphosis['Age_Normalized'] = scaler.fit_transform(kyphosis[['Age']])

# %%
kyphosis['Age_Normalized']
# Out:
# 0     0.341463
# 1     0.765854
# 2     0.619512
# 3     0.004878
# 4     0.000000
#         ...
# 76    0.760976
# 77    0.121951
# 78    0.580488
# 79    0.200000
# 80    0.170732
# Name: Age_Normalized, Length: 81, dtype: float64
